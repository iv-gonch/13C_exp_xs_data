# %%
# -*- coding: utf-8 -*-

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

# %%
directory_path = "./histo_data/"

csv_file_names = [
    '1000_JENDL',
    '100_Mohr', 
    '2_Bair_1973', 
    '7_Sekharan_1967',
    '6_Brandenburg_2023', 
    '5_Walton_1957', 
    '10_Prusachenko_2022',
    '4_Febbraro_2020', 
    '1_Drotleff_1993', 
    '3_Kellogg_1989', 
    '8_Davids_1968',
    # '8_Harissopulos_2005_needs_correction',
    '11_Gao_2022'
]

# Создаём словарь датафреймов (ключ — имя файла)
dfs = {}
for csv_file in csv_file_names:
    key = csv_file  # Пример доступа: dfs['1000_JENDL'], dfs['100_Mohr'] и т.д.
    dfs[key] = pd.read_csv(csv_file + ".csv")

# %% [markdown]
# Сначала надо подравнять положение пиков по энергии
#
# Потом надо(?) подтянуть амплитуды, чтобы избавиться от систематической ошибки шкалы
